# %%
import os
import time
import subprocess


opend_path = r"moomoo_OpenD_9.6.5618_Windows\OpenD.exe"

def start_opend_headless():
    try:
        if os.name == 'nt': # Windows
                process = subprocess.Popen([opend_path], creationflags=subprocess.CREATE_NEW_CONSOLE)
        else: # Linux/macOS
            process = subprocess.Popen([opend_path])
        print(f"OpenD started with PID: {process.pid}")
        return process
    except FileNotFoundError:
        print(f"Error: OpenD executable not found at {opend_path}")
        return None
opend_process = start_opend_headless()
if opend_process:
        time.sleep(5) # Wait for 5 seconds to ensure OpenD starts properly
        print("Connecting to OpenD via API...")

# launch_moomoo_openD()
# Out:
# OpenD started with PID: 26760
# Connecting to OpenD via API...

# %%
from dotenv import load_dotenv
import moomoo as moomoo
from moomoo.trade.open_trade_context import OpenSecTradeContext
import pandas as pd
import yfinance as yf
from datetime import datetime
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import re
import yfinance as yf
from typing import Optional, Dict, List

# %%
# Load environment variables from .env file
load_dotenv()

# Pipenv automatically loads KEY_PATH from your .env file
key_path = os.getenv("KEY_PATH")

if not key_path: 
    raise ValueError("KEY_PATH not found. Have you created your .env file?")

# 1. Configure the RSA private key file globally
# This sets the key path for all subsequent contexts.
moomoo.SysConfig.set_init_rsa_file(key_path)

# 2. Create the trade context and enable encryption
# is_encrypt=True tells this specific context to use the key configured above.
trade_ctx = OpenSecTradeContext(
    host='127.0.0.1',
    port=11111,
    is_encrypt=True,
    security_firm="FUTUSG"
    )

def account_list(trade_obj: OpenSecTradeContext):
    ret, data = trade_obj.get_acc_list()
    if ret == moomoo.RET_OK:
        return data
    else:
        raise Exception('get_acc_list error: ', data)

display(account_list(trade_ctx))
acc_list = account_list(trade_ctx)
# Out:
# 2026-01-03 16:43:02,122 | 33652 | [open_context_base.py] _send_init_connect_sync:311: InitConnect ok: conn_id=3, host=127.0.0.1, port=11111, user_id=102089581
#                acc_id   trd_env acc_type      uni_card_num          card_num  \
# 0  283726803662729116      REAL   MARGIN  1008206356731706  1008325099371778
# 1             1437342  SIMULATE     CASH               N/A               N/A
#
#   security_firm sim_acc_type                          trdmarket_auth  \
# 0        FUTUSG          N/A  [HK, US, HKCC, SG, HKFUND, USFUND, JP]
# 1           N/A        STOCK                                    [HK]
#
#   acc_status
# 0     ACTIVE
# 1     ACTIVE
# 2026-01-03 16:43:02,976 | 33652 | [open_context_base.py] on_disconnect:383: Disconnected: conn_id=3

# %%
def account_info(trade_obj: OpenSecTradeContext):
    ret, data = trade_obj.accinfo_query(trd_env="REAL",refresh_cache=True,currency="SGD")
    if ret == moomoo.RET_OK:
        return data
    else:
        raise Exception('accinfo_query error: ', data)
display(account_info(trade_ctx))
acc_info = account_info(trade_ctx)
# Out:
#       power  max_power_short  net_cash_power  total_assets  securities_assets  \
# 0  0.013437         0.013437             0.0     53467.251           53387.58
#
#    fund_assets  bond_assets  cash  market_val     long_mv  ...  au_cash  \
# 0        79.68          0.0   0.0  53387.5656  74976.5165  ...      N/A
#
#    au_avl_withdrawal_cash  aud_net_cash_power  aud_assets  is_pdt pdt_seq  \
# 0                     N/A                 N/A         0.0     N/A     N/A
#
#   beginning_dtbp remaining_dtbp dt_call_amount dt_status
# 0            N/A            N/A            N/A       N/A
#
# [1 rows x 55 columns]

# %%
def get_positions(trade_obj: OpenSecTradeContext):
    ret, data = trade_obj.position_list_query(trd_env="REAL",refresh_cache=True)
    if ret == moomoo.RET_OK:
        return data
    else:
        raise Exception('position_list_query error: ', data)
display(get_positions(trade_ctx))
positions = get_positions(trade_ctx)
# Out:
#                     code                      stock_name position_market  \
# 0   US.NVDA270115C250000             NVDA 270115 250.00C              US
# 1     US.GRAB270115C7500               GRAB 270115 7.50C              US
# 2   US.AMZN260918C280000             AMZN 260918 280.00C              US
# 3                   US.V                            Visa              US
# 4                US.SOFI               SoFi Technologies              US
# 5   US.NVDA270115C230000             NVDA 270115 230.00C              US
# 6                US.META                  Meta Platforms              US
# 7                US.IBIT           iShares Bitcoin Trust              US
# 8                US.HIMS              Hims & Hers Health              US
# 9     US.GRAB270115C5000               GRAB 270115 5.00C              US
# 10               US.GRAB                   Grab Holdings              US
# 11               US.GOOG                      Alphabet-C              US
# 12               US.DUOL                        Duolingo              US
# 13                US.CHA                 Chagee Holdings              US
# 14               US.BMNR  Bitmine Immersion Technologies              US
# 15               US.ASTS                 AST SpaceMobile              US
# 16               US.ASML                    ASML Holding              US
# 17  US.AMZN260918C250000             AMZN 260918 250.00C              US
# 18               US.AMZN                          Amazon              US
#
#          qty  can_sell_qty  cost_price  cost_price_valid  average_cost  \
# 0    -7.0000       -7.0000     18.2000              True       18.2000
# 1   -20.0000      -20.0000      0.9575              True        0.9575
# 2    -3.0000       -3.0000     12.6000              True       12.6000
# 3     8.0000        8.0000    326.8010              True      342.7940
# 4   124.0000      124.0000     25.1340              True       25.1340
# 5     7.0000        7.0000     23.5000              True       23.5000
# 6     3.0016        3.0016    648.2840              True      648.8070
# 7    20.0000       20.0000     60.8520              True       60.8530
# 8    60.0000       60.0000     41.7730              True       41.8450
# 9    20.0000       20.0000      1.8820              True        1.8820
# 10  260.0000      260.0000      5.2080              True        5.2080
# 11   25.0000       25.0000    182.7550              True      201.1710
# 12   10.0000       10.0000    182.4000              True      182.4000
# 13   50.0000       50.0000     13.9800              True       14.9000
# 14   55.0000       55.0000     40.1910              True       40.2010
# 15   30.0000       30.0000     42.7110              True       43.8170
# 16    4.0000        4.0000    609.6120              True      721.1390
# 17    3.0000        3.0000     21.5000              True       21.5000
# 18   11.0000       11.0000    222.5320              True      222.5320
#
#     diluted_cost  market_val  ...  today_buy_qty  today_buy_val  today_pl_val  \
# 0        18.2000   -12582.50  ...            0.0            0.0           0.0
# 1         0.9575    -1030.00  ...            0.0            0.0           0.0
# 2        12.6000    -3172.50  ...            0.0            0.0           0.0
# 3       326.8010     2771.84  ...            0.0            0.0           0.0
# 4        25.1340     3405.04  ...            0.0            0.0           0.0
# 5        23.5000    16100.00  ...            0.0            0.0           0.0
# 6       648.2840     1952.27  ...            0.0            0.0           0.0
# 7        60.8520     1018.80  ...            0.0            0.0           0.0
# 8        41.7730     2004.60  ...            0.0            0.0           0.0
# 9         1.8820     2360.00  ...            0.0            0.0           0.0
# 10        5.2080     1320.80  ...            0.0            0.0           0.0
# 11      182.7550     7883.00  ...            0.0            0.0           0.0
# 12      182.4000     1764.80  ...            0.0            0.0           0.0
# 13       13.9800      615.50  ...            0.0            0.0           0.0
# 14       40.1910     1715.45  ...            0.0            0.0           0.0
# 15       42.7110     2504.10  ...            0.0            0.0           0.0
# 16      609.6120     4655.12  ...            0.0            0.0           0.0
# 17       21.5000     5730.00  ...            0.0            0.0           0.0
# 18      222.5320     2491.50  ...            0.0            0.0           0.0
#
#     today_trd_val  today_sell_qty  today_sell_val  position_side  \
# 0             0.0             0.0             0.0          SHORT
# 1             0.0             0.0             0.0          SHORT
# 2             0.0             0.0             0.0          SHORT
# 3             0.0             0.0             0.0           LONG
# 4             0.0             0.0             0.0           LONG
# 5             0.0             0.0             0.0           LONG
# 6             0.0             0.0             0.0           LONG
# 7             0.0             0.0             0.0           LONG
# 8             0.0             0.0             0.0           LONG
# 9             0.0             0.0             0.0           LONG
# 10            0.0             0.0             0.0           LONG
# 11            0.0             0.0             0.0           LONG
# 12            0.0             0.0             0.0           LONG
# 13            0.0             0.0             0.0           LONG
# 14            0.0             0.0             0.0           LONG
# 15            0.0             0.0             0.0           LONG
# 16            0.0             0.0             0.0           LONG
# 17            0.0             0.0             0.0           LONG
# 18            0.0             0.0             0.0           LONG
#
#     unrealized_pl  realized_pl  currency
# 0        157.5000       0.0000       USD
# 1        885.0000       0.0000       USD
# 2        607.5000       0.0000       USD
# 3         29.4897     127.9438       USD
# 4        288.3900       0.0000       USD
# 5       -350.0000       0.0000       USD
# 6          4.8107       1.5700       USD
# 7       -198.2500       0.0000       USD
# 8       -506.0780       4.2785       USD
# 9      -1405.0000       0.0000       USD
# 10       -33.4090       0.0000       USD
# 11      2853.7233     460.4070       USD
# 12       -59.2000       0.0000       USD
# 13      -129.5000      46.0000       USD
# 14      -495.6100       0.5500       USD
# 15      1189.6000      33.1828       USD
# 16      1770.5639     446.1062       USD
# 17      -720.0000       0.0000       USD
# 18        43.6505       0.0000       USD
#
# [19 rows x 26 columns]

# %%
def account_cashflow(trade_obj: OpenSecTradeContext, date:str):
    ret, data = trade_obj.get_acc_cash_flow(clearing_date=date,trd_env="REAL")
    if ret == moomoo.RET_OK:
        return data
    else:
        raise Exception('get_acc_cash_flow error: ', data)
display(account_cashflow(trade_ctx, date='2025-08-26'))
cashflow = account_cashflow(trade_ctx, date='2025-08-26')
# Out:
#    cashflow_id clearing_date settlement_date currency      cashflow_type  \
# 0        91426    2025-08-26      2025-08-26      SGD  Currency Exchange
# 1        91427    2025-08-26      2025-08-26      USD  Currency Exchange
# 2       217769    2025-08-26      2025-08-26      USD  Fund Subscription
#
#   cashflow_direction  cashflow_amount  \
# 0                OUT         -6001.71
# 1                 IN          4651.51
# 2                OUT         -1762.55
#
#                                      cashflow_remark
# 0  TRANSFER FROM UNIVERSAL SECURITIES ACCOUNT (SG...
# 1  TRANSFER TO UNIVERSAL SECURITIES ACCOUNT (SGD ...
# 2       Fund Subscription#CSOP USD Money Market Fund

# %%
def get_historical_orders(trade_obj: OpenSecTradeContext):
    ret, data = trade_obj.history_order_list_query()
    if ret == moomoo.RET_OK:
        return data
    else:
        raise Exception('history_order_list_query error: ', data)

historical_orders = get_historical_orders(trade_ctx)
trade_ctx.close()
opend_process.terminate()

display(historical_orders)
# Out:
#                     code                      stock_name order_market  \
# 0                US.META                  Meta Platforms           US
# 1                US.SOFI               SoFi Technologies           US
# 2                US.META                  Meta Platforms           US
# 3                US.BMNR  Bitmine Immersion Technologies           US
# 4                US.META                  Meta Platforms           US
# 5                US.BMNR  Bitmine Immersion Technologies           US
# 6                US.META                  Meta Platforms           US
# 7                 US.CHA                 Chagee Holdings           US
# 8                US.META                  Meta Platforms           US
# 9                US.IBIT           iShares Bitcoin Trust           US
# 10                 US.BN                      Brookfield           US
# 11                US.CHA                 Chagee Holdings           US
# 12                 US.BN                      Brookfield           US
# 13               US.BMNR  Bitmine Immersion Technologies           US
# 14               US.SOFI               SoFi Technologies           US
# 15               US.HIMS              Hims & Hers Health           US
# 16               US.DUOL                        Duolingo           US
# 17               US.BMNR  Bitmine Immersion Technologies           US
# 18               US.GOOG                      Alphabet-C           US
# 19               US.HIMS              Hims & Hers Health           US
# 20               US.BMNR  Bitmine Immersion Technologies           US
# 21               US.ASML                    ASML Holding           US
# 22               US.BMNR  Bitmine Immersion Technologies           US
# 23                 US.BN                      Brookfield           US
# 24               US.BMNR  Bitmine Immersion Technologies           US
# 25               US.BMNR  Bitmine Immersion Technologies           US
# 26               US.HIMS              Hims & Hers Health           US
# 27               US.DUOL                        Duolingo           US
# 28                US.UNH                    UnitedHealth           US
# 29               US.SOFI               SoFi Technologies           US
# 30               US.GRAB                   Grab Holdings           US
# 31               US.BMNR  Bitmine Immersion Technologies           US
# 32               US.BMNR  Bitmine Immersion Technologies           US
# 33               US.GRAB                   Grab Holdings           US
# 34               US.AMZN                          Amazon           US
# 35                 US.BN                      Brookfield           US
# 36               US.GOOG                      Alphabet-C           US
# 37               US.AMZN                          Amazon           US
# 38  US.AMZN260918C195000             AMZN 260918 195.00C           US
# 39                 US.BN                      Brookfield           US
# 40               US.GOOG                      Alphabet-C           US
# 41                  US.V                            Visa           US
# 42               US.GOOG                      Alphabet-C           US
#
#    trd_side order_type   order_status            order_id      qty    price  \
# 0       BUY     NORMAL     FILLED_ALL  FS1BCEBC8FC9D27000   0.0016   664.94
# 1       BUY     NORMAL     FILLED_ALL  FS1BBFB30B0F6C5000   4.0000    26.50
# 2       BUY     NORMAL     FILLED_ALL  FS1BB69EC3217A1000   1.0000   670.00
# 3       BUY     NORMAL     FILLED_ALL  FS1BB18A88F7EC5000   5.0000    29.30
# 4       BUY     NORMAL     FILLED_ALL  FS1BB174DAA33A1000   1.0000   640.00
# 5       BUY     NORMAL     FILLED_ALL  FS1BADAA76F42C5000   8.0000    34.00
# 6       BUY     NORMAL  CANCELLED_ALL  FS1BADA2D567FA1000   1.0000   640.00
# 7       BUY     NORMAL     FILLED_ALL  FS1BADA00FC3BA1000  30.0000    15.30
# 8       BUY     NORMAL     FILLED_ALL  FS1BAB0D50B0AC5000   1.0000   636.50
# 9       BUY     NORMAL     FILLED_ALL  FS1BAB05282B6C5000   5.0000    49.60
# 10     SELL     NORMAL     FILLED_ALL  FS1BAB04240A7A1000  50.0000    46.45
# 11      BUY     NORMAL     FILLED_ALL  FS1BAB03FE562C5000  20.0000    14.30
# 12     SELL     NORMAL     FILLED_ALL  FS1BAB024E2EEC5000  40.0000    46.35
# 13      BUY     NORMAL     FILLED_ALL  FS1BA21936D16C5000   2.0000    30.33
# 14      BUY     NORMAL     FILLED_ALL  FS1BA0B6FD203A1000  10.0000    26.30
# 15      BUY     NORMAL     FILLED_ALL  FS1BA0B6A34C2C5000  10.0000    35.00
# 16      BUY     NORMAL     FILLED_ALL  FS1B9F7FA477FA1000   5.0000   176.80
# 17      BUY     NORMAL     FILLED_ALL  FS1B9F7EC3372C5000  10.0000    32.50
# 18     SELL     NORMAL     FILLED_ALL  FS1B9F7E40C56C5000   5.0000   291.30
# 19      BUY     NORMAL     FILLED_ALL  FS1B9F7BE7702C5000  10.0000    36.20
# 20      BUY     NORMAL     FILLED_ALL  FS1B9F7B5DE92C5000   6.0000    32.45
# 21     SELL     NORMAL     FILLED_ALL  FS1B9F7AF00ABA1000   1.0000  1020.00
# 22      BUY     NORMAL     FILLED_ALL  FS1B9A4FFCD87A1000   4.0000    39.30
# 23      BUY     NORMAL     FILLED_ALL  FS1B9A4F5287EC5000   5.0000    44.70
# 24      BUY     NORMAL  CANCELLED_ALL  FS1B9A4E3E1BEC5000   9.0000    39.50
# 25      BUY     NORMAL  CANCELLED_ALL  FS1B9A4A5020AC5000   9.0000    39.50
# 26      BUY     NORMAL     FILLED_ALL  FS1B9A49E56AAC5000  10.0000    37.79
# 27      BUY     NORMAL     FILLED_ALL  FS1B9A470F12EC5000   5.0000   188.00
# 28     SELL     NORMAL     FILLED_ALL  FS1B9A460BD7EC5000   5.0000   334.00
# 29     SELL     NORMAL  CANCELLED_ALL  FS1B9902E77D2C5000  10.0000    32.50
# 30      BUY     NORMAL     FILLED_ALL  FS1B8EB079EFEC5000  10.0000     5.60
# 31      BUY     NORMAL     FILLED_ALL  FS1B8EB022A7BA1000   3.0000    40.70
# 32      BUY     NORMAL     FILLED_ALL  FS1B763427A72C5000   1.0000    53.40
# 33      BUY     NORMAL     FILLED_ALL  FS1B7632F08D3A1000  20.0000     5.85
# 34      BUY     NORMAL     FILLED_ALL  FS1B7511F3386C5000   1.0000   214.00
# 35      BUY     NORMAL     FILLED_ALL  FS1B6E8B123F3A1000   6.0000    43.73
# 36      BUY     NORMAL     FILLED_ALL  FS1B6D39A96FBA1000   3.0000   241.00
# 37      BUY     NORMAL     FILLED_ALL  FS1B6BF154F83A1000   5.0000   223.40
# 38     SELL     NORMAL     FILLED_ALL  FS1B6BEEEDEF6C5000   1.0000    49.50
# 39      BUY     NORMAL     FILLED_ALL  FS1B6BE038CBAC5000   1.0000    67.48
# 40      BUY     NORMAL     FILLED_ALL  FS1B6AAC55882C5000   3.0000   248.50
# 41     SELL     NORMAL     FILLED_ALL  FS1B6AA5FD423A1000   2.0000   353.29
# 42      BUY     NORMAL     FILLED_ALL  FS1B695549766C5000   1.0000   247.20
#
#                 create_time  ... last_err_msg  remark  time_in_force  \
# 0       2025-12-23 00:00:00  ...                                 DAY
# 1   2025-12-12 11:16:10.755  ...                                 DAY
# 2   2025-12-05 10:01:14.440  ...                                 DAY
# 3   2025-12-01 11:20:27.682  ...                                 DAY
# 4   2025-12-01 09:45:44.143  ...                                 DAY
# 5   2025-11-28 11:06:02.387  ...                                 DAY
# 6   2025-11-28 10:32:41.954  ...                                 DAY
# 7   2025-11-28 10:20:35.280  ...                                 DAY
# 8   2025-11-26 10:22:28.868  ...                                 DAY
# 9   2025-11-26 09:46:50.225  ...                                 DAY
# 10  2025-11-26 09:42:23.854  ...                                 DAY
# 11  2025-11-26 09:41:45.242  ...                                 DAY
# 12  2025-11-26 09:34:22.719  ...                                 DAY
# 13  2025-11-19 11:28:08.330  ...                                 DAY
# 14  2025-11-18 09:40:30.274  ...                                 DAY
# 15  2025-11-18 09:38:58.291  ...                                 DAY
# 16  2025-11-17 11:00:12.706  ...                                 DAY
# 17  2025-11-17 10:56:22.046  ...                                 DAY
# 18  2025-11-17 10:54:08.472  ...                                 DAY
# 19  2025-11-17 10:43:52.706  ...                                 DAY
# 20  2025-11-17 10:41:31.879  ...                                 DAY
# 21  2025-11-17 10:39:39.374  ...                                 DAY
# 22  2025-11-13 10:19:35.971  ...                                 DAY
# 23  2025-11-13 10:16:41.571  ...                                 DAY
# 24  2025-11-13 10:11:58.515  ...                                 DAY
# 25  2025-11-13 09:54:48.388  ...                                 DAY
# 26  2025-11-13 09:52:59.116  ...                                 DAY
# 27  2025-11-13 09:40:35.342  ...                                 DAY
# 28  2025-11-13 09:36:09.889  ...                                 DAY
# 29  2025-11-12 10:04:20.150  ...                                 DAY
# 30  2025-11-04 09:39:23.521  ...                                 DAY
# 31  2025-11-04 09:37:54.144  ...                                 DAY
# 32  2025-10-16 10:12:40.670  ...                                 DAY
# 33  2025-10-16 10:07:22.106  ...                                 DAY
# 34  2025-10-15 13:04:45.220  ...                                 DAY
# 35  2025-10-10 11:24:34.366  ...                                 DAY
# 36  2025-10-09 10:50:24.512  ...                                 DAY
# 37  2025-10-08 10:55:54.786  ...                                 DAY
# 38  2025-10-08 10:45:24.994  ...                                 DAY
# 39  2025-10-08 09:41:09.490  ...                                 DAY
# 40  2025-10-07 11:15:58.562  ...                                 DAY
# 41  2025-10-07 10:48:15.306  ...                                 DAY
# 42  2025-10-06 10:17:10.811  ...                                 DAY
#
#    fill_outside_rth session aux_price trail_type trail_value trail_spread  \
# 0             False     RTH       N/A        N/A         N/A          N/A
# 1              True     ETH       N/A        N/A         N/A          N/A
# 2              True     ETH       N/A        N/A         N/A          N/A
# 3              True     ETH       N/A        N/A         N/A          N/A
# 4              True     ETH       N/A        N/A         N/A          N/A
# 5              True     ETH       N/A        N/A         N/A          N/A
# 6              True     ETH       N/A        N/A         N/A          N/A
# 7              True     ETH       N/A        N/A         N/A          N/A
# 8              True     ETH       N/A        N/A         N/A          N/A
# 9              True     ETH       N/A        N/A         N/A          N/A
# 10             True     ETH       N/A        N/A         N/A          N/A
# 11             True     ETH       N/A        N/A         N/A          N/A
# 12             True     ETH       N/A        N/A         N/A          N/A
# 13             True     ETH       N/A        N/A         N/A          N/A
# 14             True     ETH       N/A        N/A         N/A          N/A
# 15             True     ETH       N/A        N/A         N/A          N/A
# 16             True     ETH       N/A        N/A         N/A          N/A
# 17             True     ETH       N/A        N/A         N/A          N/A
# 18             True     ETH       N/A        N/A         N/A          N/A
# 19             True     ETH       N/A        N/A         N/A          N/A
# 20             True     ETH       N/A        N/A         N/A          N/A
# 21             True     ETH       N/A        N/A         N/A          N/A
# 22             True     ETH       N/A        N/A         N/A          N/A
# 23             True     ETH       N/A        N/A         N/A          N/A
# 24             True     ETH       N/A        N/A         N/A          N/A
# 25             True     ETH       N/A        N/A         N/A          N/A
# 26             True     ETH       N/A        N/A         N/A          N/A
# 27             True     ETH       N/A        N/A         N/A          N/A
# 28             True     ETH       N/A        N/A         N/A          N/A
# 29             True     ETH       N/A        N/A         N/A          N/A
# 30             True     ETH       N/A        N/A         N/A          N/A
# 31             True     ETH       N/A        N/A         N/A          N/A
# 32             True     ETH       N/A        N/A         N/A          N/A
# 33             True     ETH       N/A        N/A         N/A          N/A
# 34             True     ETH       N/A        N/A         N/A          N/A
# 35             True     ETH       N/A        N/A         N/A          N/A
# 36             True     ETH       N/A        N/A         N/A          N/A
# 37            False     RTH       N/A        N/A         N/A          N/A
# 38              N/A     RTH       N/A        N/A         N/A          N/A
# 39             True     ETH       N/A        N/A         N/A          N/A
# 40            False     RTH       N/A        N/A         N/A          N/A
# 41            False     RTH       N/A        N/A         N/A          N/A
# 42             True     ETH       N/A        N/A         N/A          N/A
#
#    currency
# 0       USD
# 1       USD
# 2       USD
# 3       USD
# 4       USD
# 5       USD
# 6       USD
# 7       USD
# 8       USD
# 9       USD
# 10      USD
# 11      USD
# 12      USD
# 13      USD
# 14      USD
# 15      USD
# 16      USD
# 17      USD
# 18      USD
# 19      USD
# 20      USD
# 21      USD
# 22      USD
# 23      USD
# 24      USD
# 25      USD
# 26      USD
# 27      USD
# 28      USD
# 29      USD
# 30      USD
# 31      USD
# 32      USD
# 33      USD
# 34      USD
# 35      USD
# 36      USD
# 37      USD
# 38      USD
# 39      USD
# 40      USD
# 41      USD
# 42      USD
#
# [43 rows x 23 columns]

# %%
filter_list = ['total_assets','securities_assets', 'fund_assets','bond_assets','cash','pending_asset','frozen_cash','avl_withdrawal_cash','risk_status',
               'us_cash', 'us_avl_withdrawal_cash','usd_net_cash_power','usd_assets',
               'sg_cash', 'sg_avl_withdrawal_cash','sgd_net_cash_power', 'sgd_assets']
acc_info = acc_info[filter_list]


columns_to_round = [
    'total_assets', 'securities_assets', 'fund_assets', 'bond_assets',
    'cash', 'pending_asset', 'frozen_cash', 'avl_withdrawal_cash',
    'us_cash', 'us_avl_withdrawal_cash', 'usd_net_cash_power',
    'usd_assets', 'sg_cash', 'sg_avl_withdrawal_cash',
    'sgd_net_cash_power', 'sgd_assets'
]
acc_info[columns_to_round] = acc_info[columns_to_round].round(3)

display(acc_info)
def get_cash(acc_info: pd.DataFrame) -> float:

    cash_columns = ['fund_assets', 'cash', 'pending_asset', 'frozen_cash', 'avl_withdrawal_cash',]
    return acc_info[cash_columns].sum(axis=1)[0].round(2)
print(get_cash(acc_info))

def get_total_assets(acc_info: pd.DataFrame) -> float:
    return acc_info['total_assets'][0].round(2)
print(get_total_assets(acc_info))

def get_securities_assets(acc_info: pd.DataFrame) -> float:
    return acc_info['securities_assets'][0].round(2)

print(get_securities_assets(acc_info))

def get_bond_assets(acc_info: pd.DataFrame) -> float:
    return acc_info['bond_assets'][0].round(2)
print(get_bond_assets(acc_info))
# Out:
#    total_assets  securities_assets  fund_assets  bond_assets  cash  \
# 0     53467.251           53387.58        79.68          0.0   0.0
#
#    pending_asset  frozen_cash  avl_withdrawal_cash risk_status  us_cash  \
# 0            0.0          0.0                  0.0      LEVEL5      0.0
#
#    us_avl_withdrawal_cash  usd_net_cash_power  usd_assets  sg_cash  \
# 0                     0.0              61.319    41507.82      0.0
#
#    sg_avl_withdrawal_cash  sgd_net_cash_power  sgd_assets
# 0                     0.0               0.013        0.01
# 79.68
# 53467.25
# 53387.58
# 0.0

# %%
pos_filter_col = ['code', 'stock_name', 'position_market', 'qty','diluted_cost','market_val','nominal_price', 'pl_ratio','pl_val','today_pl_val','currency']
positions = positions[pos_filter_col]
rounding_dict = {
    'diluted_cost': 3,
    'market_val': 3,
    'nominal_price': 3,
    'pl_ratio': 3,
    'pl_val': 3,
    'today_pl_val': 3
}
positions = positions.round(rounding_dict)
positions = positions.sort_values(by='market_val', ascending=False).reset_index(drop=True)
positions.rename(columns={'code': 'Symbol',
                          'stock_name':'Name',
                          'position_market':'Market',
                          'qty':'Quantity',
                          'diluted_cost':'Diluted Cost',
                          'market_val':'Market Value',
                          'nominal_price':'Current Price',
                          'pl_ratio':'P/L %',
                          'pl_val':'P/L',
                          'today_pl_val':"Today's P/L",
                          'currency':'Currency'}, inplace=True)
def extract_ticker(code: str) -> str:
    pattern = r"^[A-Z]+\.(?P<ticker>[A-Z0-9]+).*"
    match = re.match(pattern, code)
    if match:
        return match.group("ticker")
    else:
        return None
positions['Symbol'] = positions['Symbol'].apply(extract_ticker)

positions
# Out:
#                Symbol                            Name Market  Quantity  \
# 0   NVDA270115C230000             NVDA 270115 230.00C     US    7.0000
# 1                GOOG                      Alphabet-C     US   25.0000
# 2   AMZN260918C250000             AMZN 260918 250.00C     US    3.0000
# 3                ASML                    ASML Holding     US    4.0000
# 4                SOFI               SoFi Technologies     US  124.0000
# 5                   V                            Visa     US    8.0000
# 6                ASTS                 AST SpaceMobile     US   30.0000
# 7                AMZN                          Amazon     US   11.0000
# 8     GRAB270115C5000               GRAB 270115 5.00C     US   20.0000
# 9                HIMS              Hims & Hers Health     US   60.0000
# 10               META                  Meta Platforms     US    3.0016
# 11               DUOL                        Duolingo     US   10.0000
# 12               BMNR  Bitmine Immersion Technologies     US   55.0000
# 13               GRAB                   Grab Holdings     US  260.0000
# 14               IBIT           iShares Bitcoin Trust     US   20.0000
# 15                CHA                 Chagee Holdings     US   50.0000
# 16    GRAB270115C7500               GRAB 270115 7.50C     US  -20.0000
# 17  AMZN260918C280000             AMZN 260918 280.00C     US   -3.0000
# 18  NVDA270115C250000             NVDA 270115 250.00C     US   -7.0000
#
#     Diluted Cost  Market Value  Current Price  P/L %       P/L  Today's P/L  \
# 0         23.500      16100.00         23.000  -2.13  -350.000          0.0
# 1        182.755       7883.00        315.320  72.54  3314.130          0.0
# 2         21.500       5730.00         19.100 -11.16  -720.000          0.0
# 3        609.612       4655.12       1163.780  90.91  2216.670          0.0
# 4         25.134       3405.04         27.460   9.25   288.390          0.0
# 5        326.801       2771.84        346.480   6.02   157.434          0.0
# 6         42.711       2504.10         83.470  95.43  1222.783          0.0
# 7        222.532       2491.50        226.500   1.78    43.650          0.0
# 8          1.882       2360.00          1.180 -37.30 -1405.000          0.0
# 9         41.773       2004.60         33.410 -20.02  -501.800          0.0
# 10       648.284       1952.27        650.410   0.33     6.381          0.0
# 11       182.400       1764.80        176.480  -3.25   -59.200          0.0
# 12        40.191       1715.45         31.190 -22.40  -495.060          0.0
# 13         5.208       1320.80          5.080  -2.46   -33.409          0.0
# 14        60.852       1018.80         50.940 -16.29  -198.250          0.0
# 15        13.980        615.50         12.310 -11.95   -83.500          0.0
# 16         0.958      -1030.00          0.515  46.21   885.000          0.0
# 17        12.600      -3172.50         10.575  16.07   607.500          0.0
# 18        18.200     -12582.50         17.975   1.24   157.500          0.0
#
#    Currency
# 0       USD
# 1       USD
# 2       USD
# 3       USD
# 4       USD
# 5       USD
# 6       USD
# 7       USD
# 8       USD
# 9       USD
# 10      USD
# 11      USD
# 12      USD
# 13      USD
# 14      USD
# 15      USD
# 16      USD
# 17      USD
# 18      USD

# %%
'''
shares = positions[positions['Symbol'].str.len() <= 4]
options = positions[positions['Symbol'].str.len() > 4]
display(shares)
display(options)
'''
# Out:
# "\nshares = positions[positions['Symbol'].str.len() <= 4]\noptions = positions[positions['Symbol'].str.len() > 4]\ndisplay(shares)\ndisplay(options)\n"

# %%
'''
def update_current_share_price(shares: pd.DataFrame) -> pd.DataFrame:
    tickers = shares['Symbol'].dropna().unique().tolist()
    if not tickers:
        return shares
    price_data = yf.download(tickers=tickers, period='2d',
                             interval='1m',
                             progress=False,
                             prepost=True)

    if price_data.empty:
        print("Warning: Could not download share price data.")
        return shares

    # Extract the most recent price for each ticker
    # Forward-fill to propagate the last valid price, then select the last row.
    # This handles cases where some tickers may not have traded in the last minute.
    latest_prices = price_data['Close'].ffill().iloc[-1].round(decimals=3)
    price_map = latest_prices.to_dict() if isinstance(latest_prices, pd.Series) else {tickers[0]: latest_prices}
    shares['Current Price'] = shares['Symbol'].map(price_map)
    return shares
def get_price_from_custom_format(custom_option_string: str) -> Optional[float]:
    """
    Parses a custom option string, finds the contract in the yfinance
    option chain, and returns its last traded price.

    Args:
        custom_option_string: A string in the format "TICKER YYMMDD STRIKE_PRICE(C/P)"
                              e.g., "AMZN 260918 195.00C"

    Returns:
        The last price as a float, or None if not found or an error occurs.
    """
    try:
        # 1. Parse the string using a robust regular expression
        pattern = r'^(?P<ticker>[A-Z]+)\s+(?P<date>\d{6})\s+(?P<strike>[\d.]+)(?P<type>[CP])$'
        match = re.match(pattern, custom_option_string.strip())

        if not match:
            print(f"Warning: Could not parse symbol '{custom_option_string}'")
            return None

        parts = match.groupdict()
        underlying_ticker = parts['ticker']
        exp_date_str = datetime.strptime(parts['date'], '%y%m%d').strftime('%Y-%m-%d')
        strike_price = float(parts['strike'])
        option_type = parts['type']

        # 2. Fetch the option chain for the specific expiration date
        ticker_obj = yf.Ticker(underlying_ticker)
        if option_type == 'C':
            chain = ticker_obj.option_chain(exp_date_str).calls
        else:
            chain = ticker_obj.option_chain(exp_date_str).puts

        # 3. Find the specific contract by its strike price
        contract = chain[chain['strike'] == strike_price]

        # 4. Extract the price if the contract was found
        if not contract.empty:
            return contract['lastPrice'].iloc[0].round(decimals=3)
        else:
            print(f"Warning: Contract for '{custom_option_string}' not found in the option chain.")
            return None

    except Exception as e:
        print(f"Warning: An error occurred for '{custom_option_string}'. Reason: {e}")
        return None

def get_option_prices_from_list(option_list: List[str]) -> Dict[str, Optional[float]]:
    """
    Takes a list of custom option strings and returns a dictionary
    mapping each option to its current price.
    """
    price_results = {}
    for option_string in option_list:
        price_results[option_string] = get_price_from_custom_format(option_string)
    return price_results

def update_option_prices(options: pd.DataFrame) -> pd.DataFrame:
    """
    Fetches current prices for a DataFrame of options.
    """
    contracts = options['Name'].to_list()
    price_dictionary = get_option_prices_from_list(contracts)
    options['Current Price'] = options['Name'].map(price_dictionary)
    return options

'''
# Out:
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# <>:1: SyntaxWarning: invalid escape sequence '\s'
# C:\Users\hengl\AppData\Local\Temp\ipykernel_33652\3773372150.py:1: SyntaxWarning: invalid escape sequence '\s'
#   '''
# '\ndef update_current_share_price(shares: pd.DataFrame) -> pd.DataFrame:\n    tickers = shares[\'Symbol\'].dropna().unique().tolist()\n    if not tickers:\n        return shares\n    price_data = yf.download(tickers=tickers, period=\'2d\',\n                             interval=\'1m\',\n                             progress=False,\n                             prepost=True)\n\n    if price_data.empty:\n        print("Warning: Could not download share price data.")\n        return shares\n\n    # Extract the most recent price for each ticker\n    # Forward-fill to propagate the last valid price, then select the last row.\n    # This handles cases where some tickers may not have traded in the last minute.\n    latest_prices = price_data[\'Close\'].ffill().iloc[-1].round(decimals=3)\n    price_map = latest_prices.to_dict() if isinstance(latest_prices, pd.Series) else {tickers[0]: latest_prices}\n    shares[\'Current Price\'] = shares[\'Symbol\'].map(price_map)\n    return shares\ndef get_price_from_custom_format(custom_option_string: str) -> Optional[float]:\n    """\n    Parses a custom option string, finds the contract in the yfinance\n    option chain, and returns its last traded price.\n\n    Args:\n        custom_option_string: A string in the format "TICKER YYMMDD STRIKE_PRICE(C/P)"\n                              e.g., "AMZN 260918 195.00C"\n\n    Returns:\n        The last price as a float, or None if not found or an error occurs.\n    """\n    try:\n        # 1. Parse the string using a robust regular expression\n        pattern = r\'^(?P<ticker>[A-Z]+)\\s+(?P<date>\\d{6})\\s+(?P<strike>[\\d.]+)(?P<type>[CP])$\'\n        match = re.match(pattern, custom_option_string.strip())\n\n        if not match:\n            print(f"Warning: Could not parse symbol \'{custom_option_string}\'")\n            return None\n\n        parts = match.groupdict()\n        underlying_ticker = parts[\'ticker\']\n        exp_date_str = datetime.strptime(parts[\'date\'], \'%y%m%d\').strftime(\'%Y-%m-%d\')\n        strike_price = float(parts[\'strike\'])\n        option_type = parts[\'type\']\n\n        # 2. Fetch the option chain for the specific expiration date\n        ticker_obj = yf.Ticker(underlying_ticker)\n        if option_type == \'C\':\n            chain = ticker_obj.option_chain(exp_date_str).calls\n        else:\n            chain = ticker_obj.option_chain(exp_date_str).puts\n\n        # 3. Find the specific contract by its strike price\n        contract = chain[chain[\'strike\'] == strike_price]\n\n        # 4. Extract the price if the contract was found\n        if not contract.empty:\n            return contract[\'lastPrice\'].iloc[0].round(decimals=3)\n        else:\n            print(f"Warning: Contract for \'{custom_option_string}\' not found in the option chain.")\n            return None\n\n    except Exception as e:\n        print(f"Warning: An error occurred for \'{custom_option_string}\'. Reason: {e}")\n        return None\n\ndef get_option_prices_from_list(option_list: List[str]) -> Dict[str, Optional[float]]:\n    """\n    Takes a list of custom option strings and returns a dictionary\n    mapping each option to its current price.\n    """\n    price_results = {}\n    for option_string in option_list:\n        price_results[option_string] = get_price_from_custom_format(option_string)\n    return price_results\n\ndef update_option_prices(options: pd.DataFrame) -> pd.DataFrame:\n    """\n    Fetches current prices for a DataFrame of options.\n    """\n    contracts = options[\'Name\'].to_list()\n    price_dictionary = get_option_prices_from_list(contracts)\n    options[\'Current Price\'] = options[\'Name\'].map(price_dictionary)\n    return options\n\n'

# %%
'''
shares = update_current_share_price(shares)
options = update_option_prices(options)
display(shares)
display(options)
'''
# Out:
# '\nshares = update_current_share_price(shares)\noptions = update_option_prices(options)\ndisplay(shares)\ndisplay(options)\n'

# %%
'''
portfolio_df = pd.concat([shares, options], ignore_index=True)
display(portfolio_df)
'''
# Out:
# '\nportfolio_df = pd.concat([shares, options], ignore_index=True)\ndisplay(portfolio_df)\n'

# %%
'''
def update_market_val(portfolio_df: pd.DataFrame) -> None:
    # 1. Create a boolean mask: a Series of True/False for each row.
    is_option = portfolio_df['Symbol'].str.len() > 4

    # 2. Use np.where to create a new Series with the correct quantity for each row.
    effective_quantity = np.where(
        is_option,                      # Condition: For each row, is it an option?
        portfolio_df['Quantity'] * 100, # Value if True: Use Quantity * 100
        portfolio_df['Quantity']        # Value if False: Use just the Quantity
    )

    # 3. Use the new 'effective_quantity' for the final calculation.
    portfolio_df['Market Value'] = (portfolio_df['Current Price'].fillna(0) * effective_quantity).round(2)

def update_pl(portfolio_df: pd.DataFrame) -> None:
    is_option = portfolio_df['Symbol'].str.len() > 4
    effective_quantity = np.where(is_option, 
                                  portfolio_df['Quantity'] * 100, 
                                  portfolio_df['Quantity'])
    portfolio_df['P/L'] = ((portfolio_df['Current Price'].fillna(0) - portfolio_df['Diluted Cost'].fillna(0)) * effective_quantity).round(2)

def update_pl_ratio(portfolio_df: pd.DataFrame) -> None:
     # Use np.divide to safely handle potential division by zero
    pl_ratio_numeric = np.divide(portfolio_df['Current Price'] - portfolio_df['Diluted Cost'], portfolio_df['Diluted Cost']) * 100
    portfolio_df['P/L %'] = pl_ratio_numeric.round(2)
    portfolio_df['P/L %'] = portfolio_df['P/L %'].apply(
        lambda x: f"+{x:.2f}%" if x > 0 else f"{x:.2f}%"
    )
'''

'''
update_market_val(positions)
update_pl(positions)
update_pl_ratio(positions)
'''
# update % of Portfolio not done yet
def update_portfolio_percentage(portfolio_df: pd.DataFrame) -> None:
    total_market_value = portfolio_df['Market Value'].sum()
    if total_market_value == 0:
        portfolio_df['% of Portfolio'] = 0.0
    else:
        portfolio_df['% of Portfolio'] = (portfolio_df['Market Value'] / total_market_value * 100).round(2)
        portfolio_df['% of Portfolio'] = portfolio_df['% of Portfolio'].apply(
            lambda x: f"{x:.2f}%"
        )

update_portfolio_percentage(positions)
portfolio_df = positions.sort_values(by='Market Value', ascending=False, ignore_index=True)

display(portfolio_df)
# Out:
#                Symbol                            Name Market  Quantity  \
# 0   NVDA270115C230000             NVDA 270115 230.00C     US    7.0000
# 1                GOOG                      Alphabet-C     US   25.0000
# 2   AMZN260918C250000             AMZN 260918 250.00C     US    3.0000
# 3                ASML                    ASML Holding     US    4.0000
# 4                SOFI               SoFi Technologies     US  124.0000
# 5                   V                            Visa     US    8.0000
# 6                ASTS                 AST SpaceMobile     US   30.0000
# 7                AMZN                          Amazon     US   11.0000
# 8     GRAB270115C5000               GRAB 270115 5.00C     US   20.0000
# 9                HIMS              Hims & Hers Health     US   60.0000
# 10               META                  Meta Platforms     US    3.0016
# 11               DUOL                        Duolingo     US   10.0000
# 12               BMNR  Bitmine Immersion Technologies     US   55.0000
# 13               GRAB                   Grab Holdings     US  260.0000
# 14               IBIT           iShares Bitcoin Trust     US   20.0000
# 15                CHA                 Chagee Holdings     US   50.0000
# 16    GRAB270115C7500               GRAB 270115 7.50C     US  -20.0000
# 17  AMZN260918C280000             AMZN 260918 280.00C     US   -3.0000
# 18  NVDA270115C250000             NVDA 270115 250.00C     US   -7.0000
#
#     Diluted Cost  Market Value  Current Price  P/L %       P/L  Today's P/L  \
# 0         23.500      16100.00         23.000  -2.13  -350.000          0.0
# 1        182.755       7883.00        315.320  72.54  3314.130          0.0
# 2         21.500       5730.00         19.100 -11.16  -720.000          0.0
# 3        609.612       4655.12       1163.780  90.91  2216.670          0.0
# 4         25.134       3405.04         27.460   9.25   288.390          0.0
# 5        326.801       2771.84        346.480   6.02   157.434          0.0
# 6         42.711       2504.10         83.470  95.43  1222.783          0.0
# 7        222.532       2491.50        226.500   1.78    43.650          0.0
# 8          1.882       2360.00          1.180 -37.30 -1405.000          0.0
# 9         41.773       2004.60         33.410 -20.02  -501.800          0.0
# 10       648.284       1952.27        650.410   0.33     6.381          0.0
# 11       182.400       1764.80        176.480  -3.25   -59.200          0.0
# 12        40.191       1715.45         31.190 -22.40  -495.060          0.0
# 13         5.208       1320.80          5.080  -2.46   -33.409          0.0
# 14        60.852       1018.80         50.940 -16.29  -198.250          0.0
# 15        13.980        615.50         12.310 -11.95   -83.500          0.0
# 16         0.958      -1030.00          0.515  46.21   885.000          0.0
# 17        12.600      -3172.50         10.575  16.07   607.500          0.0
# 18        18.200     -12582.50         17.975   1.24   157.500          0.0
#
#    Currency % of Portfolio
# 0       USD         38.79%
# 1       USD         18.99%
# 2       USD         13.80%
# 3       USD         11.22%
# 4       USD          8.20%
# 5       USD          6.68%
# 6       USD          6.03%
# 7       USD          6.00%
# 8       USD          5.69%
# 9       USD          4.83%
# 10      USD          4.70%
# 11      USD          4.25%
# 12      USD          4.13%
# 13      USD          3.18%
# 14      USD          2.45%
# 15      USD          1.48%
# 16      USD         -2.48%
# 17      USD         -7.64%
# 18      USD        -30.31%

# %%
def get_exchange_rate(from_currency:str,to_currency:str):
    if from_currency == to_currency:
        return 1.0
    elif to_currency == 'USD':
        ticker = f"{from_currency}=X"
    else:
        ticker = f"{from_currency}{to_currency}=X"
    price_data = yf.download(tickers=ticker, period='2d',
                             auto_adjust=True,
                             interval='1m',
                             progress=False,
                             prepost=True)

    if price_data.empty:
        print("Warning: Could not download share price data.")
        return 

    # Extract the most recent price for each ticker
    # Forward-fill to propagate the last valid price, then select the last row.
    # This handles cases where some tickers may not have traded in the last minute.
    latest_price = price_data['Close'].ffill().iloc[-1].round(decimals=3).item()
    return latest_price

def convert_currency(value, from_currency, to_currency):
    """Converts a given amount from one currency to another."""
    rate = get_exchange_rate(from_currency, to_currency)
    if rate:
        converted_amount = value * rate
        return round(converted_amount, 2)
    else:
        return None

def marketval_of_secrities_sgd(security:str,portfolio_df: pd.DataFrame) -> float:
    if security not in ['Shares', 'Options']:
        raise ValueError("Invalid security type. Must be 'Shares' or 'Options'.")
    elif security == 'Shares':
        df = portfolio_df[portfolio_df['Symbol'].str.len() <= 4]
    elif security == 'Options':
        df = portfolio_df[portfolio_df['Symbol'].str.len() > 4]
    converted_series = df.apply(
                                lambda row: convert_currency(row['Market Value'], row['Currency'], 'SGD'), axis=1
                                )
    return converted_series.sum().round(2)
shares_in_sgd = marketval_of_secrities_sgd('Shares', portfolio_df)
options_in_sgd = marketval_of_secrities_sgd('Options', portfolio_df)

 
def plot_asset_class_allocation(portfolio_df: pd.DataFrame) -> None:
    """
    Plots a bar chart showing the total market value in Shares vs. Options.
    """
    # Create a temporary 'Asset Type' column for grouping
    asset_classes = {
            'Shares': shares_in_sgd,
            'Options': options_in_sgd,
            'Cash': get_cash(acc_info),
            'Bonds': get_bond_assets(acc_info)
            }
    filtered_assets = {k: v for k, v in asset_classes.items() if v > 0}

    plt.figure(figsize=(8, 8))
    colours = ['#4c72b0', '#c44e52', '#55a868', '#8172b3', '#ccb974', '#64b5cd']
    plt.pie(
            filtered_assets.values(),
            labels=filtered_assets.keys(),
            autopct='%1.1f%%',
            startangle=90,
            explode=[0.05] * (len(filtered_assets.keys())), # Explode all slices slightly for better visibility
            colors=colours
            )
    plt.title('Asset Class Allocation by Market Value', fontsize=16)
    plt.ylabel('') # Hide the y-label as it's not needed for a pie chart
    plt.show()

plot_asset_class_allocation(portfolio_df)

# %%
def plot_portfolio_composition(portfolio_df: pd.DataFrame) -> None:
    

    # Sort by Market Value to make the chart easier to read
    sorted_df = portfolio_df.sort_values(by='Market Value', ascending=False)

    plt.figure(figsize=(10, 6))
    sns.barplot(x='Market Value', y='Name', data=sorted_df, hue='Name', palette='Dark2', legend=False)
    plt.title('Portfolio Composition by Market Value', fontsize=16)
    plt.xlabel('Market Value ($)')
    plt.ylabel('Name')
    plt.gca().get_xaxis().set_major_formatter(
        plt.FuncFormatter(lambda x, p: f'${x:,.0f}')
    )
    plt.grid(axis='x', linestyle='--', alpha=0.7)
    plt.show()
plot_portfolio_composition(positions)

# %%
def plot_pl_by_position(portfolio_df: pd.DataFrame) -> None:
    """
    Plots a bar chart showing the P/L for each position, colored by profit or loss.
    """
    # Sort by P/L for a more organized chart
    sorted_df = portfolio_df.sort_values(by='P/L', ascending=False)
    
    # Create a color palette for the bars
    colors = ["#00d63d" if x > 0 else "#dd2a13" for x in sorted_df['P/L']]
    
    plt.figure(figsize=(12, 8))
    sns.barplot(
        x='P/L',
        y='Name',
        data=sorted_df,
        hue='Name',
        palette=colors,
        legend=False
    )
    plt.title('Profit/Loss by Position', fontsize=16)
    plt.xlabel('Profit/Loss ($)')
    plt.ylabel('Stock Name')
    plt.grid(axis='x', linestyle='--', alpha=0.7)
    plt.show()
    
plot_pl_by_position(positions)

# %%
# Use .loc to filter for 'FILLED_ALL' status and select columns in one go
historical_orders = historical_orders.loc[historical_orders['order_status'] == 'FILLED_ALL', 
                                          ['code', 'stock_name','order_market', 'trd_side','order_status','qty', 'price','currency']]
historical_orders
# Out:
#                     code                      stock_name order_market  \
# 0                US.META                  Meta Platforms           US
# 1                US.SOFI               SoFi Technologies           US
# 2                US.META                  Meta Platforms           US
# 3                US.BMNR  Bitmine Immersion Technologies           US
# 4                US.META                  Meta Platforms           US
# 5                US.BMNR  Bitmine Immersion Technologies           US
# 7                 US.CHA                 Chagee Holdings           US
# 8                US.META                  Meta Platforms           US
# 9                US.IBIT           iShares Bitcoin Trust           US
# 10                 US.BN                      Brookfield           US
# 11                US.CHA                 Chagee Holdings           US
# 12                 US.BN                      Brookfield           US
# 13               US.BMNR  Bitmine Immersion Technologies           US
# 14               US.SOFI               SoFi Technologies           US
# 15               US.HIMS              Hims & Hers Health           US
# 16               US.DUOL                        Duolingo           US
# 17               US.BMNR  Bitmine Immersion Technologies           US
# 18               US.GOOG                      Alphabet-C           US
# 19               US.HIMS              Hims & Hers Health           US
# 20               US.BMNR  Bitmine Immersion Technologies           US
# 21               US.ASML                    ASML Holding           US
# 22               US.BMNR  Bitmine Immersion Technologies           US
# 23                 US.BN                      Brookfield           US
# 26               US.HIMS              Hims & Hers Health           US
# 27               US.DUOL                        Duolingo           US
# 28                US.UNH                    UnitedHealth           US
# 30               US.GRAB                   Grab Holdings           US
# 31               US.BMNR  Bitmine Immersion Technologies           US
# 32               US.BMNR  Bitmine Immersion Technologies           US
# 33               US.GRAB                   Grab Holdings           US
# 34               US.AMZN                          Amazon           US
# 35                 US.BN                      Brookfield           US
# 36               US.GOOG                      Alphabet-C           US
# 37               US.AMZN                          Amazon           US
# 38  US.AMZN260918C195000             AMZN 260918 195.00C           US
# 39                 US.BN                      Brookfield           US
# 40               US.GOOG                      Alphabet-C           US
# 41                  US.V                            Visa           US
# 42               US.GOOG                      Alphabet-C           US
#
#    trd_side order_status      qty    price currency
# 0       BUY   FILLED_ALL   0.0016   664.94      USD
# 1       BUY   FILLED_ALL   4.0000    26.50      USD
# 2       BUY   FILLED_ALL   1.0000   670.00      USD
# 3       BUY   FILLED_ALL   5.0000    29.30      USD
# 4       BUY   FILLED_ALL   1.0000   640.00      USD
# 5       BUY   FILLED_ALL   8.0000    34.00      USD
# 7       BUY   FILLED_ALL  30.0000    15.30      USD
# 8       BUY   FILLED_ALL   1.0000   636.50      USD
# 9       BUY   FILLED_ALL   5.0000    49.60      USD
# 10     SELL   FILLED_ALL  50.0000    46.45      USD
# 11      BUY   FILLED_ALL  20.0000    14.30      USD
# 12     SELL   FILLED_ALL  40.0000    46.35      USD
# 13      BUY   FILLED_ALL   2.0000    30.33      USD
# 14      BUY   FILLED_ALL  10.0000    26.30      USD
# 15      BUY   FILLED_ALL  10.0000    35.00      USD
# 16      BUY   FILLED_ALL   5.0000   176.80      USD
# 17      BUY   FILLED_ALL  10.0000    32.50      USD
# 18     SELL   FILLED_ALL   5.0000   291.30      USD
# 19      BUY   FILLED_ALL  10.0000    36.20      USD
# 20      BUY   FILLED_ALL   6.0000    32.45      USD
# 21     SELL   FILLED_ALL   1.0000  1020.00      USD
# 22      BUY   FILLED_ALL   4.0000    39.30      USD
# 23      BUY   FILLED_ALL   5.0000    44.70      USD
# 26      BUY   FILLED_ALL  10.0000    37.79      USD
# 27      BUY   FILLED_ALL   5.0000   188.00      USD
# 28     SELL   FILLED_ALL   5.0000   334.00      USD
# 30      BUY   FILLED_ALL  10.0000     5.60      USD
# 31      BUY   FILLED_ALL   3.0000    40.70      USD
# 32      BUY   FILLED_ALL   1.0000    53.40      USD
# 33      BUY   FILLED_ALL  20.0000     5.85      USD
# 34      BUY   FILLED_ALL   1.0000   214.00      USD
# 35      BUY   FILLED_ALL   6.0000    43.73      USD
# 36      BUY   FILLED_ALL   3.0000   241.00      USD
# 37      BUY   FILLED_ALL   5.0000   223.40      USD
# 38     SELL   FILLED_ALL   1.0000    49.50      USD
# 39      BUY   FILLED_ALL   1.0000    67.48      USD
# 40      BUY   FILLED_ALL   3.0000   248.50      USD
# 41     SELL   FILLED_ALL   2.0000   353.29      USD
# 42      BUY   FILLED_ALL   1.0000   247.20      USD

# %%
shares_list = shares['Symbol'].dropna().unique().tolist()
options_list = options['Symbol'].dropna().unique().tolist()


def get_historical_share_prices(ticker_list: List[str]) -> pd.DataFrame:
    if not ticker_list:
        return pd.DataFrame()
    # Download data for all tickers at once
    price_data = yf.download(
        tickers=ticker_list,
        period='max',
        interval='1d',
        progress=True,
        prepost=False,
        auto_adjust=True # Automatically handle splits and dividends
    )
    
    if price_data.empty:
        print("Warning: Could not download historical price data for any tickers.")
        return pd.DataFrame()
    
    # Extract the 'Close' prices
    if isinstance(price_data.columns, pd.MultiIndex):
        if 'Close' in price_data.columns.get_level_values(0):
            close_prices = price_data.loc[:, ('Close', slice(None))].copy()
    else:
        close_prices = price_data[['Close']]
        if len(ticker_list) == 1:
            close_prices = close_prices.rename(columns={'Close': ticker_list[0]}) # Use ticker_list[0] for single item

    close_prices.reset_index(inplace=True)
    # Rename columns to remove MultiIndex if present
    original_columns = close_prices.columns.tolist()
    new_columns = ['Date'] + [col[1] if isinstance(col, tuple) else col for col in original_columns[1:]]
    close_prices.columns = new_columns

    close_prices['Date'] = pd.to_datetime(close_prices['Date']).dt.date

    # Round all numeric price columns to 2 decimal places
    for col in close_prices.columns:
        if col != 'Date': # Ensure we don't try to round the 'Date' column
            close_prices[col] = close_prices[col].round(3)
    
    return close_prices
    
display(get_historical_share_prices(shares_list))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 shares_list = shares['Symbol'].dropna().unique().tolist()
#       2 options_list = options['Symbol'].dropna().unique().tolist()
#       5 def get_historical_share_prices(ticker_list: List[str]) -> pd.DataFrame:
#
# NameError: name 'shares' is not defined
